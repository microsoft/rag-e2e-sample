# %%
## Requirements:
# !pip install azure-search-documents --pre
# !pip install pydantic==1.10.11

# %%
# Import required libraries  
import os
import re
import pandas as pd
import json  
import openai  
from dotenv import load_dotenv
from dotenv import dotenv_values
from tenacity import retry, wait_random_exponential, stop_after_attempt  
from azure.core.credentials import AzureKeyCredential  
from azure.search.documents import SearchClient  
from azure.search.documents.indexes import SearchIndexClient  
from azure.search.documents.models import Vector  
from azure.search.documents.indexes.models import (  
    SearchIndex,  
    SearchField,  
    SearchFieldDataType,  
    SimpleField,  
    SearchableField,  
    SearchIndex,  
    SemanticConfiguration,  
    PrioritizedFields,  
    SemanticField,  
    SearchField,  
    SemanticSettings,  
    VectorSearch,  
    HnswVectorSearchAlgorithmConfiguration
)
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
folder_path = "../DATA/transcripts" ## For step 1
chunk_size = 5000 ## For step 2: number of characters
chunk_overlap  = 100 ## For step 2
env_name = "../../llm.env" # change to use your own .env file

# %%
config = dotenv_values(env_name)

#Azure OpenAI
openai.api_type = config["OPENAI_API_TYPE"] #"azure"
openai.api_key = config['OPENAI_API_KEY']
openai.api_base = config['OPENAI_API_BASE']
openai.api_version = config['OPENAI_API_VERSION']

## Cog Search
cogsearch_name = config["COGSEARCH_NAME"] #TODO: fill in your cognitive search name
index_name = config["COGSEARCH_INDEX_NAME"] #TODO: fill in your index name: must only contain lowercase, numbers, and dashes
key = config["COGSEARCH_API_KEY"] #TODO: fill in your api key with admin key
service_endpoint = "https://"+config["COGSEARCH_NAME"] + ".search.windows.net"

credential = AzureKeyCredential(key)

# %% [markdown]
# ## Step 1: Read all files from a folder

# %%
## Read file
def read_file(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
    return content

# Extracts company name year and quarter from filename
def extractCompanyDetailsFromFilename(filename):
    pattern = r"^(.*?), (Q\d) (\d{4}).*\.txt$"
    match = re.match(pattern, filename)
    
    if match:
        company_name = match.group(1)
        quarter = match.group(2)
        year = match.group(3)
        data = [company_name, year, quarter]
        print(data)

    else:
        print("No match found.", filename)
        data = ["", "", ""]
    return data

# Extract Ticker
def extractTicker(text):
    ticker_pattern = r"Ticker:\s+(\w+)"
    ticker_match = re.search(ticker_pattern, text)
    if ticker_match:
        ticker = ticker_match.group(1)
#         print("Ticker:", ticker)
    else:
        ticker = None
        print("Ticker not found")
    return ticker


## Main Code
file_names = os.listdir(folder_path)

data = {"filename":[],
        "Company Name":[], 
        "Year":[], 
        "Quarter":[]}

for filename in file_names:
    temp = extractCompanyDetailsFromFilename(filename)
    data["filename"].append(folder_path + "/"+ filename)
    data["Company Name"].append(temp[0])
    data["Year"].append(temp[1])
    data["Quarter"].append(temp[2])
    
df = pd.DataFrame(data)

# Apply read_file function to each row and create a new 'FileContents' column
df['FileContents'] = df['filename'].apply(lambda filename: read_file(filename))

# Apply extractTicker function to each row and create a new 'Ticker' column
df['Ticker'] = df['FileContents'].apply(lambda text: extractTicker(text))
# Out:
# ['Advance Auto Parts, Inc.', '2023', 'Q1']
# ['Target Corporation', '2021', 'Q4']
# ['The Kroger Co.', '2020', 'Q4']

# %%
df.head()
# Out:
#                                             filename  \
# 0  ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 1  ../DATA/transcripts/Target Corporation, Q4 202...
# 2    ../DATA/transcripts/The Kroger Co., Q4 2020.txt
#
#                Company Name  Year Quarter  \
# 0  Advance Auto Parts, Inc.  2023      Q1
# 1        Target Corporation  2021      Q4
# 2            The Kroger Co.  2020      Q4
#
#                                         FileContents Ticker
# 0  Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 1  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 2  Company: The Kroger Co.\nTicker: KR\nISIN: US5...     KR

# %% [markdown]
# ## Step 2: Chunk FileContent

# %%
def createchunks(text, chunk_size = 25000, chunk_overlap  = 100):
    # Initialize the text splitter with custom parameters
    custom_text_splitter = RecursiveCharacterTextSplitter(
        # Set custom chunk size
        chunk_size = chunk_size,
        chunk_overlap  = chunk_overlap,
        # Use length of the text as the size measure
        length_function = len,
        # Use only "\n\n" as the separator
#         separators = ['\n']
    )

    # Create the chunks
    custom_texts = custom_text_splitter.create_documents([text])
    result = [i.page_content for i in custom_texts]
    
    return result

# Apply createchunk function to each row and create a new 'FileContentsChunked' column
df['FileContentsChunked'] = df['FileContents'].apply(lambda content: createchunks(content, chunk_size = chunk_size,chunk_overlap  = chunk_overlap))

#Explode FileContentsChunked
exploded_df = df.explode('FileContentsChunked', ignore_index=True)
exploded_df['ChunkNumber'] = exploded_df.groupby(['filename', 'Company Name', 'Year','Quarter']).cumcount() + 1

exploded_df
# Out:
#                                              filename  \
# 0   ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 1   ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 2   ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 3   ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 4   ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 5   ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 6   ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 7   ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 8   ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 9   ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 10  ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 11  ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 12  ../DATA/transcripts/Target Corporation, Q4 202...
# 13  ../DATA/transcripts/Target Corporation, Q4 202...
# 14  ../DATA/transcripts/Target Corporation, Q4 202...
# 15  ../DATA/transcripts/Target Corporation, Q4 202...
# 16  ../DATA/transcripts/Target Corporation, Q4 202...
# 17  ../DATA/transcripts/Target Corporation, Q4 202...
# 18  ../DATA/transcripts/Target Corporation, Q4 202...
# 19  ../DATA/transcripts/Target Corporation, Q4 202...
# 20  ../DATA/transcripts/Target Corporation, Q4 202...
# 21  ../DATA/transcripts/Target Corporation, Q4 202...
# 22  ../DATA/transcripts/Target Corporation, Q4 202...
# 23  ../DATA/transcripts/Target Corporation, Q4 202...
# 24  ../DATA/transcripts/Target Corporation, Q4 202...
# 25  ../DATA/transcripts/Target Corporation, Q4 202...
# 26  ../DATA/transcripts/Target Corporation, Q4 202...
# 27  ../DATA/transcripts/Target Corporation, Q4 202...
# 28  ../DATA/transcripts/Target Corporation, Q4 202...
# 29  ../DATA/transcripts/Target Corporation, Q4 202...
# 30  ../DATA/transcripts/Target Corporation, Q4 202...
# 31  ../DATA/transcripts/Target Corporation, Q4 202...
# 32  ../DATA/transcripts/Target Corporation, Q4 202...
# 33  ../DATA/transcripts/Target Corporation, Q4 202...
# 34  ../DATA/transcripts/Target Corporation, Q4 202...
# 35  ../DATA/transcripts/Target Corporation, Q4 202...
# 36  ../DATA/transcripts/Target Corporation, Q4 202...
# 37  ../DATA/transcripts/Target Corporation, Q4 202...
# 38  ../DATA/transcripts/Target Corporation, Q4 202...
# 39    ../DATA/transcripts/The Kroger Co., Q4 2020.txt
# 40    ../DATA/transcripts/The Kroger Co., Q4 2020.txt
# 41    ../DATA/transcripts/The Kroger Co., Q4 2020.txt
# 42    ../DATA/transcripts/The Kroger Co., Q4 2020.txt
# 43    ../DATA/transcripts/The Kroger Co., Q4 2020.txt
# 44    ../DATA/transcripts/The Kroger Co., Q4 2020.txt
# 45    ../DATA/transcripts/The Kroger Co., Q4 2020.txt
# 46    ../DATA/transcripts/The Kroger Co., Q4 2020.txt
# 47    ../DATA/transcripts/The Kroger Co., Q4 2020.txt
# 48    ../DATA/transcripts/The Kroger Co., Q4 2020.txt
# 49    ../DATA/transcripts/The Kroger Co., Q4 2020.txt
# 50    ../DATA/transcripts/The Kroger Co., Q4 2020.txt
#
#                 Company Name  Year Quarter  \
# 0   Advance Auto Parts, Inc.  2023      Q1
# 1   Advance Auto Parts, Inc.  2023      Q1
# 2   Advance Auto Parts, Inc.  2023      Q1
# 3   Advance Auto Parts, Inc.  2023      Q1
# 4   Advance Auto Parts, Inc.  2023      Q1
# 5   Advance Auto Parts, Inc.  2023      Q1
# 6   Advance Auto Parts, Inc.  2023      Q1
# 7   Advance Auto Parts, Inc.  2023      Q1
# 8   Advance Auto Parts, Inc.  2023      Q1
# 9   Advance Auto Parts, Inc.  2023      Q1
# 10  Advance Auto Parts, Inc.  2023      Q1
# 11  Advance Auto Parts, Inc.  2023      Q1
# 12        Target Corporation  2021      Q4
# 13        Target Corporation  2021      Q4
# 14        Target Corporation  2021      Q4
# 15        Target Corporation  2021      Q4
# 16        Target Corporation  2021      Q4
# 17        Target Corporation  2021      Q4
# 18        Target Corporation  2021      Q4
# 19        Target Corporation  2021      Q4
# 20        Target Corporation  2021      Q4
# 21        Target Corporation  2021      Q4
# 22        Target Corporation  2021      Q4
# 23        Target Corporation  2021      Q4
# 24        Target Corporation  2021      Q4
# 25        Target Corporation  2021      Q4
# 26        Target Corporation  2021      Q4
# 27        Target Corporation  2021      Q4
# 28        Target Corporation  2021      Q4
# 29        Target Corporation  2021      Q4
# 30        Target Corporation  2021      Q4
# 31        Target Corporation  2021      Q4
# 32        Target Corporation  2021      Q4
# 33        Target Corporation  2021      Q4
# 34        Target Corporation  2021      Q4
# 35        Target Corporation  2021      Q4
# 36        Target Corporation  2021      Q4
# 37        Target Corporation  2021      Q4
# 38        Target Corporation  2021      Q4
# 39            The Kroger Co.  2020      Q4
# 40            The Kroger Co.  2020      Q4
# 41            The Kroger Co.  2020      Q4
# 42            The Kroger Co.  2020      Q4
# 43            The Kroger Co.  2020      Q4
# 44            The Kroger Co.  2020      Q4
# 45            The Kroger Co.  2020      Q4
# 46            The Kroger Co.  2020      Q4
# 47            The Kroger Co.  2020      Q4
# 48            The Kroger Co.  2020      Q4
# 49            The Kroger Co.  2020      Q4
# 50            The Kroger Co.  2020      Q4
#
#                                          FileContents Ticker  \
# 0   Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 1   Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 2   Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 3   Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 4   Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 5   Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 6   Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 7   Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 8   Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 9   Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 10  Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 11  Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 12  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 13  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 14  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 15  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 16  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 17  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 18  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 19  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 20  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 21  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 22  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 23  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 24  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 25  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 26  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 27  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 28  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 29  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 30  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 31  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 32  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 33  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 34  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 35  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 36  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 37  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 38  Company: Target Corporation\nTicker: TGT\nISIN...    TGT
# 39  Company: The Kroger Co.\nTicker: KR\nISIN: US5...     KR
# 40  Company: The Kroger Co.\nTicker: KR\nISIN: US5...     KR
# 41  Company: The Kroger Co.\nTicker: KR\nISIN: US5...     KR
# 42  Company: The Kroger Co.\nTicker: KR\nISIN: US5...     KR
# 43  Company: The Kroger Co.\nTicker: KR\nISIN: US5...     KR
# 44  Company: The Kroger Co.\nTicker: KR\nISIN: US5...     KR
# 45  Company: The Kroger Co.\nTicker: KR\nISIN: US5...     KR
# 46  Company: The Kroger Co.\nTicker: KR\nISIN: US5...     KR
# 47  Company: The Kroger Co.\nTicker: KR\nISIN: US5...     KR
# 48  Company: The Kroger Co.\nTicker: KR\nISIN: US5...     KR
# 49  Company: The Kroger Co.\nTicker: KR\nISIN: US5...     KR
# 50  Company: The Kroger Co.\nTicker: KR\nISIN: US5...     KR
#
#                                   FileContentsChunked  ChunkNumber
# 0   Company: Advance Auto Parts, Inc.\nTicker: AAP...            1
# 1   This work helped us refine price targets for e...            2
# 2   With that, I'll now turn the call over to Jeff...            3
# 3   With that,  let's open it up for questions. Op...            4
# 4   The challenge is twofold. We're not getting en...            5
# 5   So they established those targets for each cat...            6
# 6   Most of the progress we've made so far has com...            7
# 7   to think about it.<br>The next question comes ...            8
# 8   I think I've got very strong resilient team he...            9
# 9   We're going to continue to look for ways to dr...           10
# 10  In terms of second quarter, again, we expect d...           11
# 11  seeing improvements there, so we do believe th...           12
# 12  Company: Target Corporation\nTicker: TGT\nISIN...            1
# 13  The second takeaway stems from a question I've...            2
# 14  In 2016, we had about 30 small format stores. ...            3
# 15  Our multi-category merchandise portfolio is a ...            4
# 16  A lot of you probably saw this last spring in ...            5
# 17  Finally, I want to touch on a body of work tha...            6
# 18  In a normal year, we just spent months prepari...            7
# 19  But the years we spent building a rock-solid f...            8
# 20  Our construction and store design teams also a...            9
# 21  The second is the robotic ships order we've be...           10
# 22  We'll also open a number of midsized stores to...           11
# 23  So today, after a year of record growth, I wan...           12
# 24  Digital is one of those opportunities. As John...           13
# 25  While I'm on the topic, I want to pause and ad...           14
# 26  The middle stage of the funnel involves questi...           15
# 27  On the SG&A expense line this year, we'll be a...           16
# 28  As you know, last year turned out to be a very...           17
# 29  Now I'll turn it back over to Brian for some c...           18
# 30  [Break]<br>Ladies and gentlemen, thank you for...           19
# 31  And now I think we just punctuate that further...           20
# 32  So we'll see how that plays out in March and A...           21
# 33  I think when it comes to Shipt and obviously, ...           22
# 34  To your question around design, the investment...           23
# 35  The other thing that the stores give us that h...           24
# 36  As we leverage our multi-category portfolio, w...           25
# 37  So we see a guest shopping all of our categori...           26
# 38  Operator, it looks like we've got time for one...           27
# 39  Company: The Kroger Co.\nTicker: KR\nISIN: US5...            1
# 40  Kroger continues to invest in digital as we bu...            2
# 41  Our full year 2019 results demonstrated clear ...            3
# 42  OG&A cost as a rate of sales, excluding fuel a...            4
# 43  As part of our review process in the fourth qu...            5
# 44  In terms of pharmacy expectations and fuel, Ga...            6
# 45  I guess just to build on a couple of points, K...            7
# 46  I would say that this is very much a sort of a...            8
# 47  I mentioned some of the things in one of the e...            9
# 48  I would say that the way that we're approachin...           10
# 49  Anytime market share becomes available, we're ...           11
# 50  I don't know, Gary, any specifics that you wou...           12

# %% [markdown]
# ## Step 3: Create Embeddings

# %%
## Make it fast by changing min, max below
# @retry(wait=wait_random_exponential(min=1, max=20), stop=stop_after_attempt(6))
def createEmbeddings(text):
    response = openai.Embedding.create(input=text , engine=config["OPENAI_DEPLOYMENT_EMBEDDING"])
    embeddings = response['data'][0]['embedding']
    return embeddings

# %%
# Apply the read_file function to each row and create a new 'FileContents' column
exploded_df['embeddings'] = exploded_df['FileContentsChunked'].apply(lambda content: createEmbeddings(content))

exploded_df.head()
# Out:
#                                             filename  \
# 0  ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 1  ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 2  ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 3  ../DATA/transcripts/Advance Auto Parts, Inc., ...
# 4  ../DATA/transcripts/Advance Auto Parts, Inc., ...
#
#                Company Name  Year Quarter  \
# 0  Advance Auto Parts, Inc.  2023      Q1
# 1  Advance Auto Parts, Inc.  2023      Q1
# 2  Advance Auto Parts, Inc.  2023      Q1
# 3  Advance Auto Parts, Inc.  2023      Q1
# 4  Advance Auto Parts, Inc.  2023      Q1
#
#                                         FileContents Ticker  \
# 0  Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 1  Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 2  Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 3  Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
# 4  Company: Advance Auto Parts, Inc.\nTicker: AAP...    AAP
#
#                                  FileContentsChunked  ChunkNumber  \
# 0  Company: Advance Auto Parts, Inc.\nTicker: AAP...            1
# 1  This work helped us refine price targets for e...            2
# 2  With that, I'll now turn the call over to Jeff...            3
# 3  With that,  let's open it up for questions. Op...            4
# 4  The challenge is twofold. We're not getting en...            5
#
#                                           embeddings
# 0  [-0.004789761733263731, -0.01100434735417366, ...
# 1  [-0.019902214407920837, -0.0029587557073682547...
# 2  [-0.0056537180207669735, -0.00646374374628067,...
# 3  [-0.007415952626615763, -0.01084926351904869, ...
# 4  [-0.00788076687604189, -0.009041925892233849, ...

# %% [markdown]
# #### Step 4:  Store the embeddings in Azure Cognitive Search Vector Store
#
# [AzureCogSearch](https://learn.microsoft.com/en-us/azure/search/search-what-is-azure-search) provides a simple interface to create a vector database, store and retrieve data using vector search. You can read more about [here](https://github.com/Azure/cognitive-search-vector-pr/tree/main) more about Vector Search.
#
# There are two steps to store data in AzureCogSearch vector database:
# - First, we create the index (or schema) of the vector database
# - Second, we add the chunked documents and their embeddings to the vector datastore

# %%
# Create a search index
index_client = SearchIndexClient(
    endpoint=service_endpoint, credential=credential)
fields = [
    SimpleField(name="id", type=SearchFieldDataType.String, key=True, sortable=True, filterable=True, facetable=True),
    SearchableField(name="CompanyName", type=SearchFieldDataType.String, filterable=True),
    SearchableField(name="Year", type=SearchFieldDataType.String, filterable=True),
    SearchableField(name="Quarter", type=SearchFieldDataType.String, filterable=True),
    SearchableField(name="Ticker", type=SearchFieldDataType.String, filterable=True),
    SearchableField(name="FileContentsChunked", type=SearchFieldDataType.String, searchable=True),
    SearchableField(name="ChunkNumber", type=SearchFieldDataType.String, filterable=True),
    
    SearchField(name="contentVector", type=SearchFieldDataType.Collection(SearchFieldDataType.Single),
                searchable=True, vector_search_dimensions=1536, vector_search_configuration="my-vector-config"),
]

vector_search = VectorSearch(
    algorithm_configurations=[
        HnswVectorSearchAlgorithmConfiguration(
            name="my-vector-config",
            kind="hnsw",
            parameters={
                "m": 4,
                "efConstruction": 400,
                "efSearch": 500,
                "metric": "cosine"
            }
        )
    ]
)

semantic_config = SemanticConfiguration(
    name="my-semantic-config",
    prioritized_fields=PrioritizedFields(
        title_field=SemanticField(field_name="Ticker"),
#         prioritized_keywords_fields=[SemanticField(field_name="category")],
        prioritized_content_fields=[SemanticField(field_name="FileContentsChunked")]
    )
)

# Create the semantic settings with the configuration
semantic_settings = SemanticSettings(configurations=[semantic_config])

# Create the search index with the semantic settings
index = SearchIndex(name=index_name, fields=fields,
                    vector_search=vector_search, semantic_settings=semantic_settings)
result = index_client.create_or_update_index(index)
print(f' {result.name} created')
# Out:
#  example_v1 created

# %%
## Upload data to Index
def batch_append_payload(df, search_client):
    """append payload for batch insertion (note: max 1000 rows per insertion) of embeddings to Cognitive Search"""
    value_list = []
    for index, row in df.iterrows():
        value_list.append(
            {
                "id": str(index),
                "CompanyName": row["Company Name"],
                "Year": row["Year"],
                "Quarter": row["Quarter"],
                "Ticker": row["Ticker"],
#                 "FileContents": row["FileContents"],
                "FileContentsChunked": row["FileContentsChunked"],
                "ChunkNumber": str(row["ChunkNumber"]),
                "contentVector": row['embeddings'],
#                 "@search.action": "upload"
            }
        )
        
#         print(len(value_list))
        
        if len(value_list)>= 1000:
            result = search_client.upload_documents(value_list)
            print(f"Uploaded {len(value_list)} payload")
            value_list = []
            
    result = search_client.upload_documents(value_list)
    print(f"Uploaded {len(value_list)} payload")
    
            
            
#     print('payload of size {}'.format(len(value_list)))

    return value_list


search_client = SearchClient(endpoint=service_endpoint, index_name=index_name, credential=credential)
payload = batch_append_payload(exploded_df, search_client)
 
# print(f"Uploaded {len(payload)} payload")
# Out:
# payload of size 51
# Uploaded 51 payload

# %% [markdown]
# ## Search Types 1: Pure Vector Search

# %%
# Pure Vector Search
query = "Advanced Auto parts earning call for year 2022 for Quarter 2"  
  
search_client = SearchClient(service_endpoint, index_name, credential=credential)
vector = Vector(value=createEmbeddings(query), k=2, fields="contentVector")
  
results = search_client.search(  
    search_text=None,  
    vectors= [vector],
#     select=["Ticker", "Quarter", "Year"],
)

# results
  
for result in results: 
    print(result['Ticker'])
    print(result['Quarter'])
    print(result['Year'])
    break
# Out:
# AAP
# Q1
# 2023

# %% [markdown]
# ## Search Types 2: Pure Filter

# %%
results = search_client.search(  
    search_text=None,  
    filter="(Ticker eq 'AAP') and (Year eq '2023') and (Quarter eq 'Q1') ",
)  

for result in results:
    print(f"Ticker: {result['Ticker']}")
    print(f"Quarter: {result['Quarter']}") 
    print(f"Year: {result['Year']}") 
    print(f"ChunkNumber: {result['ChunkNumber']}") 
    print()

#     break
# Out:
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 1
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 4
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 10
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 3
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 5
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 6
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 12
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 8
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 7
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 9
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 2
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 11

# %% [markdown]
# ## Search Types 3: Vector Search with filters

# %%
# Pure Vector Search with Filter
query = "What are the KPIs?"  
  
search_client = SearchClient(service_endpoint, index_name, credential=credential)  
vector = Vector(value=createEmbeddings(query), k=5, fields="contentVector")  

results = search_client.search(  
    search_text=None,  
    vectors=[vector],
    filter="(Ticker eq 'AAP') and (Year eq '2023') and (Quarter eq 'Q1') ",
#     select=["Ticker", "Quarter", "Year"],
)  
  
for result in results:
    print(f"Ticker: {result['Ticker']}")
    print(f"Quarter: {result['Quarter']}") 
    print(f"Year: {result['Year']}") 
    print(f"ChunkNumber: {result['ChunkNumber']}") 
    print()

#     break
# Out:
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 6
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 10
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 1
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 5
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 7

# %% [markdown]
# ## Search Types 4: Hybrid Search with filters

# %%
# Pure Vector Search with Filter
query = "What are the KPIs?"  
  
search_client = SearchClient(service_endpoint, index_name, credential=credential)  
vector = Vector(value=createEmbeddings(query), k=5, fields="contentVector")  

results = search_client.search(  
    search_text=query,  
    vectors=[vector],
    filter="(Ticker eq 'AAP') and (Year eq '2023') and (Quarter eq 'Q1') ",
#     select=["Ticker", "Quarter", "Year"],
    top = 3
)  
  
for result in results:
    print(f"Ticker: {result['Ticker']}")
    print(f"Quarter: {result['Quarter']}") 
    print(f"Year: {result['Year']}") 
    print(f"ChunkNumber: {result['ChunkNumber']}") 
    print()

#     break
# Out:
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 1
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 10
#
# Ticker: AAP
# Quarter: Q1
# Year: 2023
# ChunkNumber: 6
