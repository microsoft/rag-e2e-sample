# %% [markdown]
# ## Benchmark Question-Answer Generation

# %% [markdown]
# This notebook demonstrates how we can generate a set of Questions and Answers based on chunks from a database. Data sampled from WikiHow dataset is used as example

# %% [markdown]
# ### SET UP AND CONFIGURATION

# %% [markdown]
# Load Environment File

# %%
from dotenv import dotenv_values
from azure.keyvault.secrets import SecretClient
from azure.identity import DefaultAzureCredential
import openai

# specify the name of the .env file name 
env_name = "../../../.env" # change to your own .env file name
config = dotenv_values(env_name)

# %%
"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see 
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""

if config['KEYS_FROM'] == "KEYVAULT":
    print('keyvault was selected.')
    keyVaultName = config["KEY_VAULT_NAME"]
    KVUri = f"https://{keyVaultName}.vault.azure.net"

    credential = DefaultAzureCredential()
    client = SecretClient(vault_url=KVUri, credential=credential)
    openai.api_type = client.get_secret("OPENAI-API-TYPE").value
    openai.api_key = client.get_secret("OPENAI-API-KEY").value
    openai.api_base = client.get_secret("OPENAI-API-BASE").value
    openai.api_version = client.get_secret("OPENAI-API-VERSION").value
    
else:
    print('.env was selected.')
    openai.api_type = config["OPENAI_API_TYPE"] 
    openai.api_key = config["OPENAI_API_KEY"]
    openai.api_base = config["OPENAI_API_BASE"] 
    openai.api_version = config["OPENAI_API_VERSION"]
# Out:
# .env was selected.

# %%
openai.api_base
# Out:
# 'https://appliedaistudio-aiservices1658415937.openai.azure.com'

# %% [markdown]
# Read Chunks from csv (see step2 notebook from preprocessing subdirectory)

# %%
import os, ast
import pandas as pd 

df = pd.read_csv(f'{os.getcwd()}\..\\data\\wikihow1000.csv')

df.head()
# Out:
#                                             headline  \
# 0  \nPlace skis with bases up on a solid surface....
# 1  \nUse “raise” as instructed.,\nUse "rise” as i...
# 2  \nWalk to a place with obstacles or enemies th...
# 3  \nSlide your feet into the back pockets of the...
# 4  \nUtilize the Firefox add-on/Extensions page.,...
#
#                                               title  \
# 0              How to Repair Gouges in a Ski's Base
# 1               How to Use Commonly Misused Words12
# 2                        How to Die in Mario Games5
# 3                         How to Make Jean Slippers
# 4  How to Install Gmail Notifier Add on for Firefox
#
#                                                 text
# 0   If you have access to a vice, secure skis in ...
# 1  \n\n\nRaise means "lift" and is a transitive v...
# 2                                                 ,,
# 3   The pockets should fit your feet comfortably....
# 4   Click on the link with add-ons\n\n, You get a...

# %%
df.shape
# Out:
# (1000, 3)

# %% [markdown]
# #### Prompt Template
# ##### Write a Prompt Template. The prompt template should include all filter keys, so they can be referenced and input.

# %%
template = """
        You are given a chunk of text, which represents a part WikiHow knowledge base article, as input. 
        You will generate {n} relevant questions and answers pairs based on the input. Question may be high-level or specific.
        The question should be formed based on information in both the chunks of text. But don't use exact phrasing from the given text, assume that the person who asks question has never seen the article and wondering about some topic that's covered in it.
        The answers should be available in the text. Do not generate answers on your own.  If answer is not available in the text, just write N/A.
               
        An example is:   "How do I plant a cherry blossom tree in my garden?"
       
        You should analyze content of the article and think of possible questions that might lead user to it. Questions may be of different types: problem-solving, open,  reasoning, etc.
        input_text: {chunk_text1}
        """

# %% [markdown]
# #### Randomly pick subset of data

# %%
df_elements = df.sample(n=50)
df_elements.head()
# Out:
#                                               headline  \
# 239  \nQuit the program.,\nDrag the icon off the Do...
# 703  \nHold your breath.When you hold your breath, ...
# 169  \nPrep the chocolate.,\nBoil the cream.,\nBlen...
# 887  \nMake a home for it!,\nGet it some clothes!,\...
# 676  \nStart your Xbox 360.\n\n,\nWhen it is starti...
#
#                                                  title  \
# 239  How to Add and Remove a Program Icon From the ...
# 703      How to Get Rid of Hiccups When You Are Drunk1
# 169               How to Make Chocolate Whipped Cream3
# 887             How to Care for a Webkinz Dreamy Sheep
# 676          How to Delete the Cache on Your Xbox 3602
#
#                                                   text  \
# 239   All programs will appear on the Dock while th...
# 703   Since hiccups seem to be associated with a re...
# 169   Chop 4 ounces dark chocolate into small piece...
# 887   First get a box decorate with stickers and co...
# 676  ,, The Xbox should run faster and have improve...
#
#                                                     qa
# 239  [{'chat_history': '[]', 'question': 'How can I...
# 703                                                NaN
# 169                                                NaN
# 887                                                NaN
# 676                                                NaN

# %%
chunk1 = df_elements['text'].iloc[0]
chunk1
# Out:
# ' To create perfect candy cane lips, you want the white to be very pigmented and opaque. In order to achieve this, you want to conceal the natural redness of your lips that could show through the white lipstick. Use a makeup sponge to dab concealer over your lips, making sure to cover the entire surface.\n\n\n\n\n\n\n\n, After applying you concealer, it’s important to set it with a powder. Otherwise, you’ll be applying lip product over a creamy base, and you’ll end up with a smudged mess. Use your makeup sponge to press the powder into your lips, covering all of the concealer.\n\n\n\n\n\n\n\n\nBrush off any excess powder with a fluffy brush.\n\n, You can purchase a white lip liner at any beauty supply store. First, outline your lips entirely. This is a helpful first step, because it will define the border that has been concealed. Instead of just lining your lips, however, you’re going to use the lip liner to fill in the entirety of your lips.\n\n\n\n\n\n\n\n, The white lip liner creates a really nice base for a white lipstick to adhere to. Carefully apply your white lipstick over the white eyeliner, making sure that every bit of your lips is opaque. If the white lipstick you use is creamy, dab it with translucent powder when you’re finished. If the lipstick is matte, you don’t need to do this.\n\n\n\n\n\n\n\n, After your lips are completely white, it’s time to turn them into a candy cane! For this step, you’ll need red liquid lipstick and a small lip brush. Dip your lip brush into the liquid lipstick, and start creating diagonal stripes down your lips. Let your mouth rest naturally, so you can create lines that continue from the top lip straight down to the bottom lip.\n\n\n\n\n\n\n\n\nAlternate between thick stripes of red and thin stripes of red, to mimic the pattern of real candy canes.\nContinue creating these stripes diagonally across your lips until they are covered.\n\n'

# %%
df_elements.shape
# Out:
# (50, 3)

# %% [markdown]
# #### Generate Questions (using Azure OpenAI only)

# %%
import os
from openai import AzureOpenAI

client = AzureOpenAI(
  api_key = openai.api_key,  
  api_version = openai.api_version,
  azure_endpoint = openai.api_base
)

response = client.chat.completions.create(
    model="gpt-4-32k", # model = "deployment_name".
    messages=[
        {"role": "system", "content":"You are a creative generator of questions and answers for the given text." },
        {"role": "user", "content": template.format(chunk_text1=chunk1, n = 1)}
    ]
)

#print(response)
# print(response.model_dump_json(indent=2))
print(response.choices[0].message.content)

#TODO: Add cells showing adding tools to the chat completion. It is an update to functionc calling feature. Function calling feature is not available in the current version of the API.OpenAI version > 1.0.0.
# Out:
# Question: How can I create a candy cane lip makeup look?
#
# Answer: To create a candy cane lip makeup look, begin by concealing the natural redness of your lips with a concealer, making it very pigmented and opaque. Set the concealer with a powder to avoid a smudged mess. Next, purchase a white lip liner and use it to outline and fill your lips completely. Then, apply a white lipstick over the lip liner. If the lipstick is creamy, use translucent powder, but this is unnecessary for matte lipstick. The final step involves applying red liquid lipstick in diagonal stripes alternated between thick and thin to mimic the pattern of candy canes.

# %%
def generate_qa(chunk1, n1=1, source =''):   
    response = client.chat.completions.create(
        model="gpt-4-32k", # model = "deployment_name".
        messages=[
            {"role": "system", "content":"You are a generator of questions and answers for the given text." },
            {"role": "user", "content": template.format(chunk_text1=chunk1, n = n1)}
        ]
    )

    qa_string = response.choices[0].message.content
    # Parse the string into rows
    rows = [row.strip() for row in qa_string.split('\n') if row.strip()]

    # Separate questions and answers
    questions = [row.split(": ", 1)[1] for i, row in enumerate(rows) if i % 2 == 0]
    answers = [row.split(": ", 1)[1] for i, row in enumerate(rows) if (i - 1) % 2 == 0]

    # Combine into a list of dictionaries
    qa_data = [{"chat_history": "[]", "question": q, "answer": a, "source": source} for q, a in zip(questions, answers)]

    return qa_data

# %%
import time

max_retries=3

df_elements = df_elements.reset_index(drop=True)

for index, row in df_elements.iterrows():
        print(f"start working on {index}")
        retries = 0
        while retries < max_retries:
            try:
                df_elements.at[index, 'qa'] = generate_qa(row['text'],2,row['title'])
                print(f"successfully completed processing {index}")       
                break  # Successfully applied function, exit loop
            except Exception as e:
                print(f"Error applying function to  row {index}: {e}")
                print("context: ", row['text'])
                retries += 1
                time.sleep(1)  # Optional: Add a delay between retries
# Out:
# start working on 0
# successfully completed processing 0
# start working on 1
# successfully completed processing 1
# start working on 2
# successfully completed processing 2
# start working on 3
# successfully completed processing 3
# start working on 4
# successfully completed processing 4
# start working on 5
# successfully completed processing 5
# start working on 6
# successfully completed processing 6
# start working on 7
# successfully completed processing 7
# start working on 8
# successfully completed processing 8
# start working on 9
# successfully completed processing 9
# start working on 10
# successfully completed processing 10
# start working on 11
# successfully completed processing 11
# start working on 12
# successfully completed processing 12
# start working on 13
# successfully completed processing 13
# start working on 14
# successfully completed processing 14
# start working on 15
# successfully completed processing 15
# start working on 16
# successfully completed processing 16
# start working on 17
# successfully completed processing 17
# start working on 18
# successfully completed processing 18
# start working on 19
# successfully completed processing 19
# start working on 20
# successfully completed processing 20
# start working on 21
# successfully completed processing 21
# start working on 22
# successfully completed processing 22
# start working on 23
# successfully completed processing 23
# start working on 24
# successfully completed processing 24
# start working on 25
# successfully completed processing 25
# start working on 26
# successfully completed processing 26
# start working on 27
# successfully completed processing 27
# start working on 28
# successfully completed processing 28
# start working on 29
# successfully completed processing 29
# start working on 30
# successfully completed processing 30
# start working on 31
# successfully completed processing 31
# start working on 32
# successfully completed processing 32
# start working on 33
# successfully completed processing 33
# start working on 34
# successfully completed processing 34
# start working on 35
# successfully completed processing 35
# start working on 36
# successfully completed processing 36
# start working on 37
# Error applying function to  row 37: list index out of range
# context:  ;
# ,,,,,,,,,,,,,,
# Error applying function to  row 37: list index out of range
# context:  ;
# ,,,,,,,,,,,,,,
# Error applying function to  row 37: list index out of range
# context:  ;
# ,,,,,,,,,,,,,,
# start working on 38
# successfully completed processing 38
# start working on 39
# successfully completed processing 39
# start working on 40
# successfully completed processing 40
# start working on 41
# successfully completed processing 41
# start working on 42
# successfully completed processing 42
# start working on 43
# successfully completed processing 43
# start working on 44
# successfully completed processing 44
# start working on 45
# successfully completed processing 45
# start working on 46
# successfully completed processing 46
# start working on 47
# successfully completed processing 47
# start working on 48
# successfully completed processing 48
# start working on 49
# successfully completed processing 49

# %% [markdown]
# Print output

# %%
df_elements
# Out:
#                                              headline  \
# 0   \nQuit the program.,\nDrag the icon off the Do...
# 1   \nHold your breath.When you hold your breath, ...
# 2   \nPrep the chocolate.,\nBoil the cream.,\nBlen...
# 3   \nMake a home for it!,\nGet it some clothes!,\...
# 4   \nStart your Xbox 360.\n\n,\nWhen it is starti...
# 5   \nTake a deep breath when you are angry: Thoug...
# 6   \nGet a small cooler.,\nPlace your ice tray, m...
# 7   \nPosition the back light.,\nAdjust the intens...
# 8   \nRemove your old countertop.,\nMeasure the co...
# 9   \nSauté sliced onion in olive oil until starti...
# 10  \nOpen the web browser of your choice.,\nOpen ...
# 11  \nConsider the fact that there are at least fo...
# 12  \nOpen the Message+ app.,\nTap ☰.,\nSlide Driv...
# 13  \nPlace skis with bases up on a solid surface....
# 14  \nBlend together almost equal parts of room te...
# 15  \nCompare prices.,\nConsider pattern.,\nLook a...
# 16  \nLearn about PayPal's services by familiarizi...
# 17  \nConsult with your doctor or midwife first.,\...
# 18  \nPlace birds in a box, not a cage.,\nPlace th...
# 19  \nThe programmer’s calculator performs calcula...
# 20  \nVisit the website for your state’s governing...
# 21  \nRight-click ⊞ Win.,\nClick Run.,\nType C:/wi...
# 22  \nDecide whether you prefer POP3 or SMTP.Hotma...
# 23  \nMix all the ingredients except the thyme and...
# 24  \nFind a quiet, featureless space.,\nFind a so...
# 25  \nBefore you do anything else, make sure that ...
# 26  \nHave the players sit in a circle and begin t...
# 27  \nTrain your dog.,\nVisit your veterinarian.,\...
# 28  \nPark the donor vehicle (live battery) next t...
# 29  \nCreate character profiles.,\nDecide on a cha...
# 30  \nLook for the ENERGY STAR® label.,\nSelecting...
# 31  \nRead quotes.,\nThink back.,\nLove yourself f...
# 32  \nGo to class.,\nTake notes.,\nParticipate in ...
# 33  \nDo your research on what "Goth" really means...
# 34  \nExercise!,\nIncorporate morning hydrotherapy...
# 35  \nBoil milk on medium high.,\nSlowly add vineg...
# 36  \nClick on the Apple menu located in the upper...
# 37  \nSoak 1 1/2 cups of uncooked rice in water fo...
# 38  \nExercise regularly.,\nCut down on alcohol.,\...
# 39  \nHeat the oven to 200 degrees Fahrenheit (93 ...
# 40  \nCut three 24-inch x 12-inch sheets of alumin...
# 41  \nDownload iTunes to your computer or phone.,\...
# 42  \nRevise your budget.,\nChange your tax withho...
# 43  \nPour an ounce of clear glue into 4-5 medium-...
# 44  \nMix a solution of vinegar and water using a ...
# 45  \nBuild family traditions with your kids.,\nPr...
# 46  \nResearch the requirements for your state.,\n...
# 47  \nPick the right tip.Choosing the right tip ca...
# 48  \nResearch the job.,\nFinish high school.,\nCo...
# 49  \nMake sure the exercise ball is in a space th...
#
#                                                 title  \
# 0   How to Add and Remove a Program Icon From the ...
# 1       How to Get Rid of Hiccups When You Are Drunk1
# 2                How to Make Chocolate Whipped Cream3
# 3              How to Care for a Webkinz Dreamy Sheep
# 4           How to Delete the Cache on Your Xbox 3602
# 5                  How to Have Anger and Be Christian
# 6                              How to Make Clear Ice2
# 7                    How to Use Three Point Lighting3
# 8                        How to Make a DIY Countertop
# 9                How to Cook Zucchini and Tomato Tian
# 10       How to Add a Website Link to the Start Menu2
# 11  How to Debrief to Promote Organizational Learning
# 12  How to Use the Driving Mode on Your Samsung Ga...
# 13               How to Repair Gouges in a Ski's Base
# 14                           How to Make Beurre Manié
# 15                                 How to Pick a Sofa
# 16                  How to Get the Most Out of PayPal
# 17                        How to Help Labor Progress2
# 18                   How to Take Care of a Wild Bird3
# 19                    How to Use Calculator on a Mac4
# 20         How to File a Complaint Against a Realtor4
# 21          How to Get on Facebook When It's Blocked5
# 22                  How to Find Incoming Mail Server3
# 23                            How to Make Tomato Jam1
# 24                         How to Meditate on Breath1
# 25            How to Edit wikiHow Using an iPod Touch
# 26                                   How to Play Buzz
# 27      How to Keep Small Pets Safe Around a New Dog1
# 28                       How to Hook up Jumper Cables
# 29             How to Create a Character Driven Book2
# 30                    How to Cut Water Heating Costs3
# 31                             How to Have Good Vibes
# 32             How to Be a Successful College Student
# 33  How to Have Fashionable Budget Friendly Gothic...
# 34            How to Look Refreshed when You Wake Up4
# 35                               How to Make Rasmulla
# 36                      How to Turn off Mac Firewall2
# 37                          How to Make Korean Dakjuk
# 38            How to Cope With Anxiety and Depression
# 39                         How to Make Organic Candy1
# 40             How to Cook Lasagna in Your Dishwasher
# 41                             How to Find New Music3
# 42                      How to Give Yourself a Raise1
# 43                         How to Make Rainbow Slime2
# 44               How to Remove Ink Stains from Jeans3
# 45  How to Improve Your Children's Sibling Relatio...
# 46                         How to Establish Residency
# 47               How to Use an Airless Paint Sprayer1
# 48                           How to Be a Loan Officer
# 49          How to Do Push Ups With an Exercise Ball1
#
#                                                  text  \
# 0    All programs will appear on the Dock while th...
# 1    Since hiccups seem to be associated with a re...
# 2    Chop 4 ounces dark chocolate into small piece...
# 3    First get a box decorate with stickers and co...
# 4   ,, The Xbox should run faster and have improve...
# 5   ;\n, If angry at a person, it generally helps ...
# 6    Just a regular cooler is fine, like the one y...
# 7    The back light's role is to provide a glowing...
# 8    Work slowly and carefully to ensure that you ...
# 9    Add red pepper slices and cook until tender. ...
# 10   Select a browser that you use often and are f...
# 11   Alone, each of these methods has singular uti...
# 12   It's a red app with a pair of white speech bu...
# 13   If you have access to a vice, secure skis in ...
# 14   There should always be slightly more butter t...
# 15   If this one is more expensive, but better, bu...
# 16  \n\n\nFunds pull from your bank account to cov...
# 17   Even though activities such as having sex or ...
# 18   Wild birds are not domesticated like house bi...
# 19   It can convert values to hexadecimal, octal, ...
# 20   Real estate agents are licensed by the state....
# 21   It's in the bottom left corner of your screen...
# 22   Mail both offer POP3 and IMAP incoming mail s...
# 23   To start, add the tomatoes, sugar, vinegar, w...
# 24   Find a space without loud noises or noticeabl...
# 25   wikiHow's mobile site is not geared towards f...
# 26   For example:\n\n\nsupposing the players have ...
# 27   Properly training your new dog is essential t...
# 28   Position the vehicles so that the batteries a...
# 29   Character profiles can be useful tools in a c...
# 30   If you’re on the market for a new dishwasher ...
# 31   On a daily basis, read inspirational quotes. ...
# 32   Don't rely on a "magic number" of classes you...
# 33   There are many different looks within this su...
# 34   Everyone knows exercise is good for your body...
# 35  ;\n,,,,,,,,,,,, Stir occasionally so milk does...
# 36  ,,,,\n\n\nSelect the radio button next to "Set...
# 37                                  ;\n,,,,,,,,,,,,,,
# 38   Not only does regular exercise reduce the lik...
# 39   Line a baking sheet with an oven-safe silicon...
# 40  ;\n,,,,,, Top with herbs and spices.\n\n,, Beg...
# 41   In order to access the music on iTunes, you'l...
# 42   Cut down on everything except for fixed expen...
# 43  , Stir well with a craft stick.\n\n, Add a cou...
# 44   Make sure the water is cool and not hot. Heat...
# 45   One of the great ways you can help strengthen...
# 46   Most states have their own rules for determin...
# 47   Larger tips generally require more pressure, ...
# 48   Before deciding that being a loan officer is ...
# 49  ;\n,,,, Align your shoulders and wrists and yo...
#
#                                                    qa
# 0   [{'chat_history': '[]', 'question': 'How can I...
# 1   [{'chat_history': '[]', 'question': 'What are ...
# 2   [{'chat_history': '[]', 'question': 'What is t...
# 3   [{'chat_history': '[]', 'question': 'How can I...
# 4   [{'chat_history': '[]', 'question': 'What are ...
# 5   [{'chat_history': '[]', 'question': 'What can ...
# 6   [{'chat_history': '[]', 'question': 'What is t...
# 7   [{'chat_history': '[]', 'question': 'What is t...
# 8   [{'chat_history': '[]', 'question': 'What are ...
# 9   [{'chat_history': '[]', 'question': 'Why is eg...
# 10  [{'chat_history': '[]', 'question': 'How can I...
# 11  [{'chat_history': '[]', 'question': 'What step...
# 12  [{'chat_history': '[]', 'question': 'What feat...
# 13  [{'chat_history': '[]', 'question': 'How can I...
# 14  [{'chat_history': '[]', 'question': 'Why is ha...
# 15  [{'chat_history': '[]', 'question': 'What are ...
# 16  [{'chat_history': '[]', 'question': 'What func...
# 17  [{'chat_history': '[]', 'question': 'What are ...
# 18  [{'chat_history': '[]', 'question': 'What is t...
# 19  [{'chat_history': '[]', 'question': 'What can ...
# 20  [{'chat_history': '[]', 'question': 'How does ...
# 21  [{'chat_history': '[]', 'question': 'How can t...
# 22  [{'chat_history': '[]', 'question': 'When shou...
# 23  [{'chat_history': '[]', 'question': 'What is t...
# 24  [{'chat_history': '[]', 'question': 'What are ...
# 25  [{'chat_history': '[]', 'question': 'Why am I ...
# 26  [{'chat_history': '[]', 'question': 'What woul...
# 27  [{'chat_history': '[]', 'question': 'Why is it...
# 28  [{'chat_history': '[]', 'question': 'How shoul...
# 29  [{'chat_history': '[]', 'question': 'Why is cr...
# 30  [{'chat_history': '[]', 'question': 'What are ...
# 31  [{'chat_history': '[]', 'question': 'How can a...
# 32  [{'chat_history': '[]', 'question': 'What are ...
# 33  [{'chat_history': '[]', 'question': 'What are ...
# 34  [{'chat_history': '[]', 'question': 'What bene...
# 35  [{'chat_history': '[]', 'question': 'How often...
# 36  [{'chat_history': '[]', 'question': 'How can I...
# 37                                                NaN
# 38  [{'chat_history': '[]', 'question': 'How does ...
# 39  [{'chat_history': '[]', 'question': 'What is t...
# 40  [{'chat_history': '[]', 'question': 'How shoul...
# 41  [{'chat_history': '[]', 'question': 'How can I...
# 42  [{'chat_history': '[]', 'question': 'How can s...
# 43  [{'chat_history': '[]', 'question': 'What do I...
# 44  [{'chat_history': '[]', 'question': 'What shou...
# 45  [{'chat_history': '[]', 'question': 'What are ...
# 46  [{'chat_history': '[]', 'question': 'What are ...
# 47  [{'chat_history': '[]', 'question': 'What is t...
# 48  [{'chat_history': '[]', 'question': 'What are ...
# 49  [{'chat_history': '[]', 'question': 'How shoul...

# %% [markdown]
# We have to clean data, because at least one of the rows was invalid.

# %%
qa1 = df_elements['qa'].iloc[0]
qa1
# Out:
# [{'chat_history': '[]',
#   'question': 'How can I identify if a program is open on the Dock?',
#   'answer': 'A program is open if it has a small dot next to the Dock icon, even if no windows are open.',
#   'source': 'How to Add and Remove a Program Icon From the Dock of a Mac Computer2'},
#  {'chat_history': '[]',
#   'question': 'What steps should I follow to remove a program from the Dock?',
#   'answer': 'You can remove a program from the Dock by right-clicking the icon (or holding Control and clicking) and selecting "Quit" or "Force Quit" to close the program. Then, click and hold the program icon and drag it at least a third of the way across the screen, away from the Dock. Make sure not to release the mouse button too soon as the program will just jump back to the Dock. Wait until the program icon turns transparent. Then you can release it and see an animation resembling a poof of smoke, indicating the program icon has been removed from the Dock. Or use a drop down menu by right-clicking the icon, hovering over "Options," and selecting "Remove from Dock."',
#   'source': 'How to Add and Remove a Program Icon From the Dock of a Mac Computer2'}]

# %%
df_clean = df_elements[df_elements['qa'].notna()]
df_clean.shape
# Out:
# (49, 4)

# %%
# Explode the 'qa' column into separate rows
df_expanded = df_clean.explode('qa')

# Extract 'chat_history', 'question', and 'answer' from the exploded 'qa' column
df_expanded['chat_history'] = df_expanded['qa'].apply(lambda x: x['chat_history'])
df_expanded['question'] = df_expanded['qa'].apply(lambda x: x['question'])
df_expanded['answer'] = df_expanded['qa'].apply(lambda x: x['answer'])

# Drop the original 'qa' column
df_expanded.drop(columns=['qa'], inplace=True)

# %%
df_expanded = df_expanded.rename(columns={'text': 'context', 'title': 'source'})
df_expanded.head()
# Out:
#                                             headline  \
# 0  \nQuit the program.,\nDrag the icon off the Do...
# 0  \nQuit the program.,\nDrag the icon off the Do...
# 1  \nHold your breath.When you hold your breath, ...
# 1  \nHold your breath.When you hold your breath, ...
# 2  \nPrep the chocolate.,\nBoil the cream.,\nBlen...
#
#                                               source  \
# 0  How to Add and Remove a Program Icon From the ...
# 0  How to Add and Remove a Program Icon From the ...
# 1      How to Get Rid of Hiccups When You Are Drunk1
# 1      How to Get Rid of Hiccups When You Are Drunk1
# 2               How to Make Chocolate Whipped Cream3
#
#                                              context chat_history  \
# 0   All programs will appear on the Dock while th...           []
# 0   All programs will appear on the Dock while th...           []
# 1   Since hiccups seem to be associated with a re...           []
# 1   Since hiccups seem to be associated with a re...           []
# 2   Chop 4 ounces dark chocolate into small piece...           []
#
#                                             question  \
# 0  How can I identify if a program is open on the...
# 0  What steps should I follow to remove a program...
# 1  What are some recommended techniques to stop h...
# 1  What should one do if the hiccups persist for ...
# 2  What is the process of making chocolate ganach...
#
#                                               answer
# 0  A program is open if it has a small dot next t...
# 0  You can remove a program from the Dock by righ...
# 1  The text suggests several techniques such as h...
# 1  The text suggests that if hiccups last longer ...
# 2  To make chocolate ganache with dark chocolate,...

# %%
df_out = df_expanded[["chat_history", "question", "answer", "source", "context"]]
df_out.head(3)
# Out:
#   chat_history                                           question  \
# 0           []  How can I identify if a program is open on the...
# 0           []  What steps should I follow to remove a program...
# 1           []  What are some recommended techniques to stop h...
#
#                                               answer  \
# 0  A program is open if it has a small dot next t...
# 0  You can remove a program from the Dock by righ...
# 1  The text suggests several techniques such as h...
#
#                                               source  \
# 0  How to Add and Remove a Program Icon From the ...
# 0  How to Add and Remove a Program Icon From the ...
# 1      How to Get Rid of Hiccups When You Are Drunk1
#
#                                              context
# 0   All programs will appear on the Dock while th...
# 0   All programs will appear on the Dock while th...
# 1   Since hiccups seem to be associated with a re...

# %% [markdown]
# **Note on text structuring and format:** We could chain another llm call to convert to a format suitable to be saved to csv. The prompt can be modified to provide answer in this form directly. But, it is left as an exercise for the user to update prompt to work with whatever format they want to use. Here we split and reorganize the format output by the model using python, for the promptflow sample.
#
# **Note on csv dataset format choice:** csv is a customer requirement, and a proper way can be to log them to a database and populate them.

# %%
df_out.to_csv(f'{os.getcwd()}\..\\data\\wikihow_eval_qa.csv', index=False)
