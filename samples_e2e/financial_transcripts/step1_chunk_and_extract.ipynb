# %%
from dotenv import dotenv_values
from pathlib import Path

# specify the name of the .env file name 
env_name = "../../llm.env" # change to your own .env file name
config = dotenv_values(env_name)

# %% [markdown]
# # Extract data and context

# %%
# code to extract text from pdf 
"""
This code sample shows Prebuilt Document operations with the Azure Form Recognizer client library. 
The async versions of the samples require Python 3.6 or later.

To learn more, please visit the documentation - Quickstart: Form Recognizer Python client library SDKs
https://docs.microsoft.com/en-us/azure/applied-ai-services/form-recognizer/quickstarts/try-v3-python-sdk
"""

from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

"""
Remember to remove the key from your code when you're done, and never post it publicly. For production, use
secure methods to store and access your credentials. For more information, see 
https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-security?tabs=command-line%2Ccsharp#environment-variables-and-application-configuration
"""

endpoint = config["AZURE_FORM_RECOGNIZER_ENDPOINT"]
key = config["AZURE_FORM_RECOGNIZER_KEY"]

# sample document
document_analysis_client = DocumentAnalysisClient(
        endpoint=endpoint, credential=AzureKeyCredential(key)
    )


def analyze_pdf(doc_path):  
    with open(doc_path, "rb") as f:
        poller = document_analysis_client.begin_analyze_document(
            "prebuilt-document", document=f
        )
    result = poller.result()
                
    return result

# %%
import re
# Extract value if explicity mentioned in a text. You may develop the template for specific use case
extract_name1 = "Ticker"  
extract_name2= "Quarter"
def extract_values(text, target =["FY"]):
    '''
    given a text string, extract the client code and line of business
    '''
    extract_name1_pattern = r"{extract_name1}\s+([\w,]+)"
    extract_name2_pattern = r"{extract_name2}\s+([\w\s]+)"

    extract_name1_match = re.search(extract_name1_pattern, text)
    extract_name1_match = re.search(extract_name2_pattern, text)

    if extract_name1_match and extract_name1_match:
        extract_name1 = filter_id1_match.group(1).split(',')  # Split by commas to get a list
        extract_name2 = filter_id2_match.group(1).split()[0]  # Extract only the first word
        return extract_name1, extract_name2
    else:
        return None

# %%
import re
# extract information form the filename
def extract_info_from_filename(filename):
    pattern = r'([A-Z]+)TranscriptFY(\d{2})Q(\d)'
    match = re.search(pattern, filename)
    
    if match:
        symbol = match.group(1)
        fiscal_year = match.group(2)
        fiscal_quarter = match.group(3)
        return symbol, fiscal_year, fiscal_quarter
    else:
        return None

# example
filename = "MSFTTranscriptFY23Q4"
symbol, fiscal_year, fiscal_quarter = extract_info_from_filename(filename)

if symbol and fiscal_year and fiscal_quarter:
    print(f"Symbol: {symbol}")
    print(f"Fiscal Year: {fiscal_year}")
    print(f"Fiscal Quarter: {fiscal_quarter}")
else:
    print("Unable to extract information from the filename.")
# Out:
# Symbol: MSFT
# Fiscal Year: 23
# Fiscal Quarter: 4

# %%
def create_line_page_tuples(result):
    '''
    Input: result of form recognizer analyze_pdf function
    Output: Create list of tuples of the form (line, page_num, line_num) 
    This will keep reference of the line number and page number of each line in the document.
    '''
    line_page_tuples = []

    total_pages = len(result.pages)
    for page_num in range(total_pages):
        lines = result.pages[page_num].lines
        total_lines = len(lines)

        for line_num in range(total_lines):
            line = lines[line_num].content
            line_page_tuples.append((line, page_num + 1, line_num + 1))

    return line_page_tuples

# %%
def chunk_with_page_number(line_page_tuples, chunk_length=10, chunk_overlap=2):
    '''
    Given the list of tuples of the form (line, page_num, line_num) and chunk length and overlap,
    it will create chunks of text with page number and line number of the first line in the chunk.
    chunk length: number of lines in each chunk
    chunk_overlap: number of overlapping lines between chunks
    '''
    pointer = 0 
    chunks = []
    total_lines = len(line_page_tuples)
    #for line, page_number, line_number in line_page_tuples:
    while pointer < total_lines:
        line_count = 0
        current_chunk = ""
        if not chunks: 
            # for first chunk we can not use overlap
            pointer = 0
        else:
            pointer = pointer - chunk_overlap
        
        # take starting page number and line number 
        page_number, line_number = line_page_tuples[pointer][1:]  
        while line_count < chunk_length and pointer < total_lines:
            current_chunk = current_chunk + line_page_tuples[pointer][0]
            current_chunk = current_chunk + " "
            line_count += 1
            pointer += 1
        chunks.append((current_chunk, page_number, line_number))
    return chunks

# %% [markdown]
# #### Read pdf and extract symbol and quarter from file name

# %%
import os
import pandas as pd 

doc_dir = Path("DATA/")
pdf_files = [filename for filename in os.listdir(doc_dir) if filename.endswith('.pdf')]
#DocId = 0 
for file_name in pdf_files:
    values = extract_info_from_filename(file_name)
    file_path = os.path.join(doc_dir, f"{os.path.splitext(file_name)[0]}.pdf")
    # analyze the pdf using form recognizer
    result = analyze_pdf(file_path)
    # get the chunks in a tuple of the form (chunk, page_number, line_number)
    line_page_tuples = create_line_page_tuples(result)
    chunks = chunk_with_page_number(line_page_tuples=line_page_tuples, chunk_length=10, chunk_overlap=2)
    #DocId += 1   
    
    # write the chunks to another csv file 
    df_chunks = pd.DataFrame(chunks, columns = ['chunk', 'page_number', 'line_number'])  
    #df_chunks['DocId'] = DocId
    if values:
        symbol, fiscal_year, fiscal_quarter = values
        df_chunks["Ticker"] = symbol
        df_chunks["Year"] = fiscal_year
        df_chunks["Quarter"] = fiscal_quarter
    else:
        df_chunks["Ticker"] = "NULL"
        df_chunks["Year"] = "NULL"
        df_chunks["Quarter"] = "NULL"
    if not os.path.exists("AnalyzedPDF/"):
        os.makedirs("AnalyzedPDF/")

    print('writing the results of: \n' + file_name)  
    if not os.path.exists(f"AnalyzedPDF/Chunks_{file_name}.csv"):
        df_chunks.to_csv(f"AnalyzedPDF/Chunks_{file_name}.csv", index=False)
    else:
        print(f'File: chunks_{file_name}.csv already exists, skipping...')
# Out:
# writing the results of:
# MSFTTranscriptFY23Q1.pdf
# writing the results of:
# MSFTTranscriptFY23Q2.pdf
# writing the results of:
# MSFTTranscriptFY23Q3.pdf
# writing the results of:
# MSFTTranscriptFY23Q4.pdf

# %%
# read csv files in analyzedPDF folder and create a unified dataframe
import pandas as pd
import os 
def read_csv_files(path= "AnalyzedPDF/"):
    df = pd.DataFrame()
    for file in os.listdir(path):
        file_path = os.path.join(path, file)
        df = pd.concat(pd.read_csv(file_path), ignore_index=True, axis = 0)
    return df

# %%
import os 
import pandas as pd 
def concatenate_csv_files(path = "AnalyzedPDF"):
    csv_files = [file for file in os.listdir(path) if file.endswith(".csv")]
    dfs = []
    for file in csv_files:
        file_path = os.path.join(path, file)
        df = pd.read_csv(file_path)
        dfs.append(df)
    print("Concatenated files:", dfs)
    combined_df = pd.concat(dfs, ignore_index=True)
    return combined_df

# %% [markdown]
# Let's combine all the csv files and store in a combined file.

# %%
result_combined_df = concatenate_csv_files(path = "AnalyzedPDF")
print(result_combined_df)
if not os.path.exists("AnalyzedPDF/CombinedResults"):
    os.makedirs("AnalyzedPDF/CombinedResults")
# Out:
# Concatenated files: [                                                 chunk  page_number  \
# 0    Microsoft FY23 First Quarter Earnings Conferen...            1
# 1    On the Microsoft Investor Relations website, y...            1
# 2    GAAP. They are included as additional clarifyi...            1
# 3    same in constant currency, we will refer to th...            2
# 4    predictions, projections, or other statements ...            2
# ..                                                 ...          ...
# 108  This was a segment that crossed over $10 billi...           49
# 109  quality of our ROI, and we'll continue. Of cou...           50
# 110  one of the big opportunities it opens up is fo...           50
# 111  But we're going to continue to grow our third-...           51
# 112  SATYA NADELLA: Thank you very much. (Operator ...           51
#
#      line_number Ticker  Year  Quarter
# 0              1   MSFT    23        1
# 1              9   MSFT    23        1
# 2             17   MSFT    23        1
# 3              6   MSFT    23        1
# 4             14   MSFT    23        1
# ..           ...    ...   ...      ...
# 108           20   MSFT    23        1
# 109            8   MSFT    23        1
# 110           16   MSFT    23        1
# 111            3   MSFT    23        1
# 112           11   MSFT    23        1
#
# [113 rows x 6 columns],                                                  chunk  page_number  \
# 0    Microsoft FY23 Second Quarter Earnings Confere...            1
# 1    On the Microsoft Investor Relations website, y...            1
# 2    GAAP. They are included as additional clarifyi...            1
# 3    same in constant currency, we will refer to th...            1
# 4    predictions, projections, or other statements ...            2
# ..                                                 ...          ...
# 103  BRETT IVERSEN: Thanks, Brad. Joe, we have time...           31
# 104  the coming quarters? Thank you. SATYA NADELLA:...           31
# 105  going to be an Al app. That's, I think, the be...           32
# 106  Sometimes, you will have ISVs who are differen...           32
# 107  (Operator Direction.) END OF AUDIO *Complete a...           32
#
#      line_number Ticker  Year  Quarter
# 0              1   MSFT    23        2
# 1              9   MSFT    23        2
# 2             17   MSFT    23        2
# 3             25   MSFT    23        2
# 4              6   MSFT    23        2
# ..           ...    ...   ...      ...
# 103           13   MSFT    23        2
# 104           21   MSFT    23        2
# 105            1   MSFT    23        2
# 106            9   MSFT    23        2
# 107           17   MSFT    23        2
#
# [108 rows x 6 columns],                                                  chunk  page_number  \
# 0    Microsoft FY23 Third Quarter Earnings Conferen...            1
# 1    On the Microsoft Investor Relations website, y...            1
# 2    measures provided should not be considered as ...            1
# 3    for assessing how our underlying businesses pe...            2
# 4    Relations website. During this call, we will b...            2
# ..                                                 ...          ...
# 102  infrastructure apps in other areas. So, it wou...           41
# 103  Microsoft 365 suite value, which is significan...           42
# 104  that our services, as they are competitive, ge...           42
# 105  Microsoft 365 to close these loops in a new wa...           42
# 106  today's earnings call. Thank you for joining u...           43
#
#      line_number Ticker  Year  Quarter
# 0              1   MSFT    23        3
# 1              9   MSFT    23        3
# 2             17   MSFT    23        3
# 3              6   MSFT    23        3
# 4             14   MSFT    23        3
# ..           ...    ...   ...      ...
# 102           15   MSFT    23        3
# 103            2   MSFT    23        3
# 104           10   MSFT    23        3
# 105           18   MSFT    23        3
# 106            5   MSFT    23        3
#
# [107 rows x 6 columns],                                                  chunk  page_number  \
# 0    Microsoft FY23 Fourth Quarter Earnings Confere...            1
# 1    press release and financial summary slide deck...            1
# 2    to the measures of financial performance prepa...            1
# 3    effect of foreign currency rate fluctuations. ...            2
# 4    During this call, we will be making forward-lo...            2
# ..                                                 ...          ...
# 109  Can you just talk about where customers are ri...           44
# 110  complement, I'll call it, your databases, beca...           45
# 111  with a very disruptive business model. I mean,...           45
# 112  architecture lays out, our business model arou...           46
# 113  speaking with all of you soon. SATYA NADELLA: ...           46
#
#      line_number Ticker  Year  Quarter
# 0              1   MSFT    23        4
# 1              9   MSFT    23        4
# 2             17   MSFT    23        4
# 3              5   MSFT    23        4
# 4             13   MSFT    23        4
# ..           ...    ...   ...      ...
# 109           19   MSFT    23        4
# 110            7   MSFT    23        4
# 111           15   MSFT    23        4
# 112            2   MSFT    23        4
# 113           10   MSFT    23        4
#
# [114 rows x 6 columns]]
#                                                  chunk  page_number  \
# 0    Microsoft FY23 First Quarter Earnings Conferen...            1
# 1    On the Microsoft Investor Relations website, y...            1
# 2    GAAP. They are included as additional clarifyi...            1
# 3    same in constant currency, we will refer to th...            2
# 4    predictions, projections, or other statements ...            2
# ..                                                 ...          ...
# 437  Can you just talk about where customers are ri...           44
# 438  complement, I'll call it, your databases, beca...           45
# 439  with a very disruptive business model. I mean,...           45
# 440  architecture lays out, our business model arou...           46
# 441  speaking with all of you soon. SATYA NADELLA: ...           46
#
#      line_number Ticker  Year  Quarter
# 0              1   MSFT    23        1
# 1              9   MSFT    23        1
# 2             17   MSFT    23        1
# 3              6   MSFT    23        1
# 4             14   MSFT    23        1
# ..           ...    ...   ...      ...
# 437           19   MSFT    23        4
# 438            7   MSFT    23        4
# 439           15   MSFT    23        4
# 440            2   MSFT    23        4
# 441           10   MSFT    23        4
#
# [442 rows x 6 columns]

# %%
# let's rename columns, add index, and save the results
result_combined_df["Id"] = result_combined_df.index + 1 

# now let's add a unique id
columns = ['Id'] + [col for col in result_combined_df.columns if col != 'Id']
result_combined_df = result_combined_df.reindex(columns=columns)
# rename for consistency
result_combined_df.head(1000)
# Out:
#       Id                                              chunk  page_number  \
# 0      1  Microsoft FY23 First Quarter Earnings Conferen...            1
# 1      2  On the Microsoft Investor Relations website, y...            1
# 2      3  GAAP. They are included as additional clarifyi...            1
# 3      4  same in constant currency, we will refer to th...            2
# 4      5  predictions, projections, or other statements ...            2
# ..   ...                                                ...          ...
# 437  438  Can you just talk about where customers are ri...           44
# 438  439  complement, I'll call it, your databases, beca...           45
# 439  440  with a very disruptive business model. I mean,...           45
# 440  441  architecture lays out, our business model arou...           46
# 441  442  speaking with all of you soon. SATYA NADELLA: ...           46
#
#      line_number Ticker  Year  Quarter
# 0              1   MSFT    23        1
# 1              9   MSFT    23        1
# 2             17   MSFT    23        1
# 3              6   MSFT    23        1
# 4             14   MSFT    23        1
# ..           ...    ...   ...      ...
# 437           19   MSFT    23        4
# 438            7   MSFT    23        4
# 439           15   MSFT    23        4
# 440            2   MSFT    23        4
# 441           10   MSFT    23        4
#
# [442 rows x 7 columns]

# %%
# reorder the columns
# Reorder columns
new_column_order = ['Id', 'Ticker', 'Year', 'Quarter', 'chunk', 'page_number', 'line_number']
result_combined_df_reordered = result_combined_df[new_column_order]

# %%
#result_filter_id1_df.to_csv(f"../AnalyzedPDF/CombinedResults/{filter_id1_name}.csv", index=False)

# %%
'Id', 'Ticker', 'Year', 'Quarter', 'chunk', 'page_number', 'line_number'
new_columns = {
    'Id': "Id",
    "Ticker": "Ticker",
    "Year" : "Year",
    "Quarter": "Quarter",
    'chunk': 'Chunk',
    'page_number': 'PageNumber',
    'line_number': 'LineNumber',
}
result_combined_df_reordered = result_combined_df_reordered.rename(columns=new_columns)
# Print the DataFrame with 'Id' as the first column after index
result_combined_df_reordered.head(1000)
result_combined_df_reordered.to_csv("AnalyzedPDF/CombinedResults/Chunks.csv", index=False)

# %%
result_combined_df_reordered.head(3)
# Out:
#    Id Ticker  Year  Quarter  \
# 0   1   MSFT    23        1
# 1   2   MSFT    23        1
# 2   3   MSFT    23        1
#
#                                                Chunk  PageNumber  LineNumber
# 0  Microsoft FY23 First Quarter Earnings Conferen...           1           1
# 1  On the Microsoft Investor Relations website, y...           1           9
# 2  GAAP. They are included as additional clarifyi...           1          17
